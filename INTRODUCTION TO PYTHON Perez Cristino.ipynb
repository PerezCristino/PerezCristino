# %% [markdown]
# #**The history of Phyton**

# %% [markdown]
# Python was made between the late 1980s and early 1990s by Guido Van Rossum, a mathematician from the Netherlands. In 2001 the Python Software Foundation (PSF) was formed. A non-profit organization created specifically to manage all things Python intellectual property. Since then, the PSF has centralized everything related to the development of the Python language and its official interpreters.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Colab img/foto.jpg")

# %% [markdown]
# ##**The beginning**

# %% [markdown]
# On a Christmas in 1989, Guido Van Rossum, who worked at the CWI, started a project as a hobby giving continuity to ABC, a programming language that was developed at the CWI.
#
# ABC was developed in the early 80s as another option to BASIC, it was designed for beginners due to its simple operation.
#
# This project did not achieve its mission since the hardware available at the time made it difficult to use, for this reason Van Rossum gave it a second life creating Python.

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Colab img/ABC.jpg")

# %% [markdown]
# ##**Phyton** **0.9.0**

# %% [markdown]
# In 1991, Van Rossum posted the code for version 0.9.0 on alt.sources. This release had classes with inheritance, exception handling, functions, and modular types available.
#
# In the version already mentioned we already have a module system adopted from Modula-3, a structured and modular programming language. Python's exception model is similar to Modula-3.

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Colab img/phyton cero.jpg")

# %% [markdown]
# ##**Phyton 1.0**

# %% [markdown]
# In 1994 comes Python 1.0 that contains:
#
# 1.- Functional programming tools such as lambda, reduce, filter and map.
#
# 2.- Tools that came to the language thanks to a Lisp hacker, a family of multiparadigm computer programming languages.

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Colab img/lisp phyton uno.jpg")

# %% [markdown]
# The last version that was released in CWI was Python 1.2, in 1995, Van Rossum continued to work at the Corporation for National Research (CNRI) in Virginia.
#
# In version 1.4, we managed to appreciate new functions, most of them inspired by Modula-3 and also built-in support for complex numbers.
#
# In 2000, the core Python developer team switched to http://BeOpen.com to create BeOpen Python Labs. CNRI requested that version 1.6 be released the moment the team left CNRI.

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Colab img/CNRI.png")

# %% [markdown]
# ##**Phyton 2.x & 3.x**

# %% [markdown]
# All versions of Python 3.x and Python 2.x were planned to coexist for several releases that were released at the same time, where Python 2.6 was released at the same time as version 3.0, these include new features and alerts that highlight the use of tools removed in version 3.0 of Python.

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Colab img/PythonTimeline_2.png")

# %% [markdown]
# # **Print statement**

# %% [markdown]
# The print () function in Python is the most used function in the Python world, when we talk about a function in Python we mean a block of code that can do a specific function. We can think of functions as robots, each robot has a different name like print () which only works to print the words you write and you can't do more than that.
#
# In order to print a line of text, it is necessary to place the quotation marks ("").

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Colab img/hi wor.png")

# %% [markdown]
# Also with print () you can do math problems

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Colab img/Suma.png")

# %% [markdown]
# # **If-else Statement**

# %% [markdown]
# ##**if**

# %% [markdown]
# The most common conditional is the one we use in the if statement, which has the following structure:

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Colab img/If.png")

# %% [markdown]
# If the comparison (a logical expression) is true, what we write in the if block is executed, that is, everything that is indented after the condition. If the comparison is false, the program jumps to the text that are not indented.

# %% [markdown]
# ##**Indented**

# %% [markdown]
# In Python indentation is very important since it establishes blocks of code that belong to a certain function within the programming language.
#
# If we want to return to the main block, we must undo and return to the same line as the main one. For this simple reason, Python is a very organized and easy-to-read programming language, since the language itself forces us to be so.
#
# The indentation can be done with the tab, or with 4 spaces on the space bar.

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Colab img/Sang.png")

# %% [markdown]
# ##**if/else**

# %% [markdown]
# The else clause allows you to execute a set of statements if the comparison is true and a different set of statements if the comparison is false.

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Colab img/If else.png")

# %% [markdown]
# #**Loops**

# %% [markdown]
# Loops are used when you need to repeat a set of instructions, over and over again until a desired condition is met.
#
# There are two main types of loops in Python:

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Colab img/loops.png")

# %% [markdown]
# ##**for**

# %% [markdown]
# A for loop contains three operations.
# The first operation i, is to initialize the loop iterator with the first value of the iterator of the range function.
#
# The range function is supplying values as an iterator from (1,10).
#
# *for loop catches the StopIterator error and breaks the loop.*

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Colab img/FOR.png")

# %% [markdown]
# ##**While**

# %% [markdown]
# A While loop variable is initialized before the statement.
#
# Here we start i at 0. In the while statement, and it has been executed until the loop is valid.
#
# For this reason we limit it to (i <10). Inside the while loop we are printing i and then incrementing it by 1.
#
# If we don't increment i by 1 the loop will continue executing a concept called infinite loop. Eventually the program will crash.

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Colab img/while.png")

# %% [markdown]
# ##**Break**

# %% [markdown]
# An interrupt statement will stop the current loop and continue until the next
#
# Example of break:

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Colab img/Break.png")

# %% [markdown]
# ##**Continue**

# %% [markdown]
# Continue will stop the current iteration of the loop and start the next iteration.
#
# It is very useful when we have some exception cases, but we do not want to stop the loop for such scenarios.

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Colab img/continue.png")

# %% [markdown]
# The above code skips all even numbers using the if% 2 conditional check.
#
# For this reason, we print only odd numbers.
